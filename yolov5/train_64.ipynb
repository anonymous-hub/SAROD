# %%
# !python train.py --img 64 \
            --batch 256 \
            --data ./data/64.yaml \
            --cfg ./models/yolov5x.yaml \
            --weight ./weights/yolov5x.pt \
            --name 64 \
            --device 2 \
            --single-cls
            --adam
            --evolve
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# {'lr0': 0.001, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# Namespace(adam=False, batch_size=256, bucket='', cache_images=False, cfg='./models/yolov5x.yaml', data='./data/64.yaml', device='2', epochs=300, evolve=False, img_size=[64], multi_scale=False, name='64', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=True, weights='./weights/yolov5x.pt')
# Using CUDA device0 _CudaDeviceProperties(name='TITAN RTX', total_memory=24220MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
#
#               from  n    params  module                                  arguments
# ...

# %%
import warnings
warnings.simplefilter("ignore")

# %%
# GPU:1
# !python train_256.py --lr 1e-4 --cv_dir checkpoints_256 --batch_size 256 --data_dir data/256/ --alpha 0.8 --img_size 128 --test_epoch 10
# Out:
# GPU device  True
# 100%|███████████████████████████████████████████| 16/16 [00:06<00:00,  2.37it/s]
# Train: 0 | Rw: 0.263150 | S: 2.004 | V: 0.996 | #: 16
# ...
# Computing AP: 100%|███████████████████████████████| 1/1 [00:00<00:00, 51.54it/s]
# Test - AP: 0.34339211738563385 | AR : 0.8855421686746988
# Test - Rw: 0.1780 | S: 2.414 | V: 0.822 | #: 16
# 100%|███████████████████████████████████████████| 16/16 [00:05<00:00,  2.89it/s]
# Train: 1 | Rw: 0.272597 | S: 1.975 | V: 0.994 | #: 16
# ...
# Computing AP: 100%|███████████████████████████████| 1/1 [00:00<00:00, 52.10it/s]
# Test - AP: 0.3622719412272829 | AR : 0.9002677376171352
# Test - Rw: 0.1847 | S: 2.501 | V: 1.038 | #: 16
# 100%|███████████████████████████████████████████| 16/16 [00:05<00:00,  2.88it/s]
# Train: 2 | Rw: 0.234297 | S: 2.152 | V: 1.036 | #: 16
# ...
# Computing AP: 100%|███████████████████████████████| 1/1 [00:00<00:00, 58.28it/s]
# Test - AP: 0.4166798074584662 | AR : 0.9149933065595717
# ...

# %%
# !python make_map.py --weights_path checkpoints480/yolov3_ckpt_999.pth --model_def config/yolov3-custom480.cfg \
--data_config config/custom480_rl.data \
--img_size=480 --batch_size 1 --class_path data/custom480/classes.names \
--save_dir /home/cutz/SAR_OD/EfficientObjectDetection/data/800/base_dir_metric_fd
# Out:
# Namespace(batch_size=1, class_path='data/custom480/classes.names', conf_thres=0.001, data_config='config/custom480_rl.data', img_size=480, iou_thres=0.5, model_def='config/yolov3-custom480.cfg', n_cpu=8, nms_thres=0.5, save_dir='/home/cutz/SAR_OD/EfficientObjectDetection/data/800/base_dir_metric_fd', weights_path='checkpoints480/yolov3_ckpt_999.pth')
# Compute mAP...
# ...
# Computing AP: 100%|█████████████████████████████| 1/1 [00:00<00:00, 1196.66it/s]
# [[1. 0.]
#  [0. 0.]]
# P0036_4800_5600_6600_7400 saved
# ...
# Computing AP: 100%|█████████████████████████████| 1/1 [00:00<00:00, 5229.81it/s]
# [[0. 1.]
#  [0. 0.]]
# P0055_1200_2000_3600_4400 saved
#
# Computing AP: 100%|█████████████████████████████| 1/1 [00:00<00:00, 4337.44it/s]
# [[1. 0.]
#  [0. 0.]]
# P0044_2400_3200_3000_3800 saved
#
# Computing AP: 100%|█████████████████████████████| 1/1 [00:00<00:00, 4766.25it/s]
# [[0. 1.]
#  [0. 0.]]
# P0078_2400_3200_4800_5600 saved
#
# ...

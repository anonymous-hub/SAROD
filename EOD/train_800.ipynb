# %%
import warnings
warnings.simplefilter("ignore")

# %%
# !python train.py --lr 2e-5 --cv_dir checkpoints --batch_size 1024 --data_dir data/800/ --alpha 0.8 --img_size 256 --parallel
# Out:
# GPU device  True
# 100%|█████████████████████████████████████████████| 1/1 [00:10<00:00, 10.43s/it]
# Train: 0 | Rw: 0.278059 | S: 1.933 | V: 0.911 | #: 16
# ...
# Computing AP: 100%|███████████████████████████████| 1/1 [00:00<00:00, 55.58it/s]
# Test - AP: 0.6800484238100892 | AR : 0.771665410700829
# Test - Rw: 0.4427 | S: 1.358 | V: 0.529 | #: 6
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.97s/it]
# Train: 1 | Rw: 0.270529 | S: 1.963 | V: 0.955 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.90s/it]
# Train: 2 | Rw: 0.280414 | S: 1.939 | V: 0.961 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.85s/it]
# Train: 3 | Rw: 0.316313 | S: 1.902 | V: 0.915 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.96s/it]
# Train: 4 | Rw: 0.352125 | S: 1.823 | V: 0.956 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.88s/it]
# ...

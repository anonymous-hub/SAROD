# %%
import warnings
warnings.simplefilter("ignore")

# %%
# !python train_800_A2C.py --lr 1e-4 --cv_dir checkpoints_800 --batch_size 768 --data_dir data/800/ --alpha 0.8 --img_size 256 --parallel
# Out:
# GPU device  True
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.87s/it]
# Train: 0 | Rw: 0.318609 | S: 1.887 | V: 0.992 | #: 16
# ...
# Computing AP: 100%|██████████████████████████████| 1/1 [00:00<00:00, 100.33it/s]
# Test - AP: 0.5712934402289529 | AR : 0.7008289374529013
# Test - Rw: 0.1063 | S: 2.673 | V: 0.596 | #: 14
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.84s/it]
# Train: 1 | Rw: 0.333736 | S: 1.884 | V: 0.990 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.49s/it]
# Train: 2 | Rw: 0.367047 | S: 1.758 | V: 1.024 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.58s/it]
# Train: 3 | Rw: 0.393630 | S: 1.777 | V: 1.016 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.24s/it]
# Train: 4 | Rw: 0.435260 | S: 1.761 | V: 0.984 | #: 16
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.30s/it]
# ...
